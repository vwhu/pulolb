# %% [markdown]
# # Importing Matlab Files into Python
#
# You'll need to install the hdf5storage package. So go to your cmd window and type in
#
# `pip install hdf5storage`

# %%
import hdf5storage
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.io

# %% [markdown]
# On my own computer, I did everything locally and with different filenames. What you'll want to have in the quotations is just the filename since it will be in the same directory.
#
# Also, for every spot you see `data2.mat`, you'll wanted to switch it to `converted_PL11.mat` (again, just something I was whipping up on my computer)

# %%
df = hdf5storage.loadmat('converted_PL11.mat')
df2 = hdf5storage.loadmat('converted_PL03.mat')

# %%
df3 = scipy.io.loadmat('converted_PL11.mat')
df4 = scipy.io.loadmat('converted_PL03.mat')
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-3-901105a7aff3> in <module>()
# ----> 1 df3 = scipy.io.loadmat('converted_PL11.mat')
#       2 df4 = scipy.io.loadmat('converted_PL03.mat')
#
# ~\Anaconda3\lib\site-packages\scipy\io\matlab\mio.py in loadmat(file_name, mdict, appendmat, **kwargs)
#     133     """
#     134     variable_names = kwargs.pop('variable_names', None)
# --> 135     MR = mat_reader_factory(file_name, appendmat, **kwargs)
#     136     matfile_dict = MR.get_variables(variable_names)
#     137     if mdict is not None:
#
# ~\Anaconda3\lib\site-packages\scipy\io\matlab\mio.py in mat_reader_factory(file_name, appendmat, **kwargs)
#      63         return MatFile5Reader(byte_stream, **kwargs)
#      64     elif mjv == 2:
# ---> 65         raise NotImplementedError('Please use HDF reader for matlab v7.3 files')
#      66     else:
#      67         raise TypeError('Did not recognize version %s' % mjv)
#
# NotImplementedError: Please use HDF reader for matlab v7.3 files

# %%
df2.keys()
# Out:
# dict_keys(['#subsystem#', 'converted_PL03'])

# %%
# Requires 3 inputs to get to the base level of the arrays

# THIS CELL HAS DATA FROM "1st Charge"

print(df['#subsystem#'][0][0][0][2][0][0])
print('\n')
print(df['#subsystem#'][0][0][0][2][0][5])
print('\n')
len((df['#subsystem#'][0][0][0][2][0][0]))
# Out:
# [[  1.00014863e+01]
#  [  2.00169123e+01]
#  [  3.00169928e+01]
#  ...,
#  [  1.12863495e+04]
#  [  1.12963499e+04]
#  [  1.13025215e+04]]
#
#
# [[ 3.84519219]
#  [ 3.84519219]
#  [ 3.84535384]
#  ...,
#  [ 4.19239426]
#  [ 4.19239426]
#  [ 4.19239426]]
# 1132

# %%
df['#subsystem#'][0][0][0][7][0][0][0][0] # Gets time-sec
# Out:
# 'Time_sec'

# %%
df['#subsystem#'][0][0][0][15]
# Out:
# array([ ([], [], [], [], [[array([['Row']],
#       dtype='<U3'), array([['Variables']],
#       dtype='<U9')]], [[ 2.]])],
#       dtype=[('Description', '<U1', (0, 0)), ('UserData', '<f8', (0, 0)), ('VariableDescriptions', 'O', (0, 0)), ('VariableUnits', 'O', (0, 0)), ('DimensionNames', 'O', (1, 2)), ('VersionSavedFrom', '<f8', (1, 1))])

# %%
len(df['data2'])
# Out:
# 14

# %%
df['data2'][1][0]
# Out:
# array([['1st Charge']],
#       dtype='<U10')

# %%
df['#subsystem#'][0][0][0][count][0][0].flatten()
# Out:
# array([  1.00014863e+01,   2.00169123e+01,   3.00169928e+01, ...,
#          1.12863495e+04,   1.12963499e+04,   1.13025215e+04])

# %%
host_df = pd.DataFrame()

host_df['time'] = df['#subsystem#'][0][0][0][count][0][0].flatten()
host_df['datetime'] = df['#subsystem#'][0][0][0][count][0][1].flatten()
host_df['step'] = df['#subsystem#'][0][0][0][count][0][2].flatten()
host_df['cycle'] = df['#subsystem#'][0][0][0][count][0][3].flatten()
host_df['current_amp'] = df['#subsystem#'][0][0][0][count][0][4].flatten()
host_df['voltage'] = df['#subsystem#'][0][0][0][count][0][5].flatten()
host_df['charge_ah'] = df['#subsystem#'][0][0][0][count][0][6].flatten()
host_df['discharge_ah'] = df['#subsystem#'][0][0][0][count][0][7].flatten()

# %%
len(discharge_ah)
# Out:
# 1132

# %%
len(df['#subsystem#'][0][0][0])
# Out:
# 94

# %% [markdown]
# # For loop that reads in the MAT v7.3 file.
#
# What we will have to do I think is save each .mat file as a .MAT v7.3. Right now, they're a v5.0, which is a bit outdated and it has a specific type of compression that marks it as MatlabOpaque, and isn't readable outside of Matlab from what I've been trying.
#
# Basically what I did is is create an empty dictionary `data_dict` which will hold all the data. The count is for the indexing in the subsystem arrays that the hdf5storage package breaks the data down into two separate giant numpy arrays, a `#subsystem#` which holds all the table data (number) in each cell array, and a `filename` array, which has all the names of the cells in the cell array.
#
# Then I did a for loop that names the key in the dictionary, and assuming that all the data lines up between the two larger numpy arrays (I think it does, I tried my best to check), it puts all the data into a pandas dataframe, which is the value to the key in the dictionary. If you have questions, feel free to let me know. I'm starting to feel like a real coder :D
#
# The .flatten() part at each of the entries is because the hdf5storage module has each data point inputted in as it's own individual numpy array. Flatten removes that and makes it one single array, instead of an array of single-digit arrays.

# %%
data_dict_full_cycle = {}
count = 2

for idx in range(1, len(df['data2'])):
    operation = str(df['data2'][idx][0][0][0])
    start_date = str(df['data2'][idx][1][0][0])
    
    host_df = pd.DataFrame()
    
    host_df['time'] = df['#subsystem#'][0][0][0][count][0][0].flatten()
    host_df['datetime'] = df['#subsystem#'][0][0][0][count][0][1].flatten()
    host_df['step'] = df['#subsystem#'][0][0][0][count][0][2].flatten()
    host_df['cycle'] = df['#subsystem#'][0][0][0][count][0][3].flatten()
    host_df['current_amp'] = df['#subsystem#'][0][0][0][count][0][4].flatten()
    host_df['voltage'] = df['#subsystem#'][0][0][0][count][0][5].flatten()
    host_df['charge_ah'] = df['#subsystem#'][0][0][0][count][0][6].flatten()
    host_df['discharge_ah'] = df['#subsystem#'][0][0][0][count][0][7].flatten()
    
    data_dict_full_cycle[operation + ' ' + start_date] = host_df
    
    count = count + 7
    
    if count > len(df['#subsystem#'][0][0][0]):
        break
    
    #op.append(operation)
    #start_d.append(start_date)

# %%
data_dict_full_cycle['101 Full Cycles April 23, 2015']
# Out:
#                 time       datetime  step  cycle  current_amp   voltage  \
# 0       1.001540e+01  736077.443519   1.0    1.0     0.000000  4.169973
# 1       2.003091e+01  736077.443634   1.0    1.0     0.000000  4.170135
# 2       3.004658e+01  736077.443750   1.0    1.0     0.000000  4.169973
# 3       4.006213e+01  736077.443866   1.0    1.0     0.000000  4.170135
# 4       5.007753e+01  736077.443981   1.0    1.0     0.000000  4.169973
# 5       6.001490e+01  736077.444097   1.0    1.0     0.000000  4.169973
# 6       6.001516e+01  736077.444097   2.0    1.0     0.749957  4.212549
# 7       7.003073e+01  736077.444225   3.0    1.0     0.353107  4.199759
# 8       8.004626e+01  736077.444340   3.0    1.0     0.296647  4.199759
# 9       9.004630e+01  736077.444456   3.0    1.0     0.261428  4.199759
# 10      1.000616e+02  736077.444572   3.0    1.0     0.237101  4.199922
# 11      1.100772e+02  736077.444688   3.0    1.0     0.218947  4.199759
# 12      1.200927e+02  736077.444803   3.0    1.0     0.204605  4.199922
# 13      1.301082e+02  736077.444919   3.0    1.0     0.193531  4.199922
# 14      1.401238e+02  736077.445035   3.0    1.0     0.183002  4.199759
# 15      1.501393e+02  736077.445150   3.0    1.0     0.175196  4.199922
# 16      1.601548e+02  736077.445266   3.0    1.0     0.167571  4.199759
# 17      1.701549e+02  736077.445382   3.0    1.0     0.161399  4.199759
# 18      1.801702e+02  736077.445498   3.0    1.0     0.155771  4.199759
# 19      1.901857e+02  736077.445613   3.0    1.0     0.150506  4.199759
# 20      2.002012e+02  736077.445729   3.0    1.0     0.145967  4.199759
# 21      2.102167e+02  736077.445845   3.0    1.0     0.141429  4.199759
# 22      2.202323e+02  736077.445961   3.0    1.0     0.137798  4.199759
# 23      2.302479e+02  736077.446076   3.0    1.0     0.131444  4.199759
# 24      2.402634e+02  736077.446192   3.0    1.0     0.130536  4.199759
# 25      2.502788e+02  736077.446308   3.0    1.0     0.127269  4.199759
# 26      2.602944e+02  736077.446424   3.0    1.0     0.124001  4.199759
# 27      2.703104e+02  736077.446539   3.0    1.0     0.121278  4.199922
# 28      2.803254e+02  736077.446655   3.0    1.0     0.119099  4.199759
# 29      2.903409e+02  736077.446771   3.0    1.0     0.115650  4.199759
# ...              ...            ...   ...    ...          ...       ...
# 217268  2.169769e+06  736102.557674  13.0  102.0     0.000000  4.192313
# 217269  2.169779e+06  736102.557789  13.0  102.0     0.000000  4.192475
# 217270  2.169789e+06  736102.557905  13.0  102.0     0.000000  4.192313
# 217271  2.169799e+06  736102.558021  13.0  102.0     0.000000  4.192151
# 217272  2.169809e+06  736102.558137  13.0  102.0     0.000000  4.192313
# 217273  2.169819e+06  736102.558252  13.0  102.0     0.000000  4.192313
# 217274  2.169829e+06  736102.558368  13.0  102.0     0.000000  4.192313
# 217275  2.169839e+06  736102.558484  13.0  102.0     0.000000  4.192151
# 217276  2.169849e+06  736102.558600  13.0  102.0     0.000000  4.192313
# 217277  2.169859e+06  736102.558715  13.0  102.0     0.000000  4.192151
# 217278  2.169869e+06  736102.558831  13.0  102.0     0.000000  4.192151
# 217279  2.169879e+06  736102.558947  13.0  102.0     0.000000  4.191989
# 217280  2.169889e+06  736102.559063  13.0  102.0     0.000000  4.192151
# 217281  2.169899e+06  736102.559178  13.0  102.0     0.000000  4.192151
# 217282  2.169909e+06  736102.559294  13.0  102.0     0.000000  4.191989
# 217283  2.169919e+06  736102.559410  13.0  102.0     0.000000  4.191827
# 217284  2.169929e+06  736102.559525  13.0  102.0     0.000000  4.191989
# 217285  2.169939e+06  736102.559641  13.0  102.0     0.000000  4.191827
# 217286  2.169949e+06  736102.559757  13.0  102.0     0.000000  4.191989
# 217287  2.169959e+06  736102.559873  13.0  102.0     0.000000  4.191827
# 217288  2.169969e+06  736102.559988  13.0  102.0     0.000000  4.191827
# 217289  2.169979e+06  736102.560104  13.0  102.0     0.000000  4.191665
# 217290  2.169989e+06  736102.560220  13.0  102.0     0.000000  4.191665
# 217291  2.169999e+06  736102.560336  13.0  102.0     0.000000  4.191827
# 217292  2.170009e+06  736102.560451  13.0  102.0     0.000000  4.191989
# 217293  2.170019e+06  736102.560567  13.0  102.0     0.000000  4.191827
# 217294  2.170029e+06  736102.560683  13.0  102.0     0.000000  4.191665
# 217295  2.170039e+06  736102.560799  13.0  102.0     0.000000  4.191665
# 217296  2.170050e+06  736102.560914  13.0  102.0     0.000000  4.191665
# 217297  2.170057e+06  736102.561007  13.0  102.0     0.000000  4.191504
#
#            charge_ah  discharge_ah
# 0       0.000000e+00      0.000000
# 1       0.000000e+00      0.000000
# 2       0.000000e+00      0.000000
# 3       0.000000e+00      0.000000
# 4       0.000000e+00      0.000000
# 5       0.000000e+00      0.000000
# 6       5.711780e-10      0.000000
# 7       1.125534e-03      0.000000
# 8       2.022074e-03      0.000000
# 9       2.794031e-03      0.000000
# 10      3.485956e-03      0.000000
# 11      4.119177e-03      0.000000
# 12      4.707544e-03      0.000000
# 13      5.260187e-03      0.000000
# 14      5.783125e-03      0.000000
# 15      6.281089e-03      0.000000
# 16      6.757558e-03      0.000000
# 17      7.214595e-03      0.000000
# 18      7.655649e-03      0.000000
# 19      8.081491e-03      0.000000
# 20      8.494427e-03      0.000000
# 21      8.894979e-03      0.000000
# 22      9.283537e-03      0.000000
# 23      9.661385e-03      0.000000
# 24      1.002899e-02      0.000000
# 25      1.038736e-02      0.000000
# 26      1.073703e-02      0.000000
# 27      1.107845e-02      0.000000
# 28      1.141171e-02      0.000000
# 29      1.173746e-02      0.000000
# ...              ...           ...
# 217268  1.266674e+02    125.863829
# 217269  1.266674e+02    125.863829
# 217270  1.266674e+02    125.863829
# 217271  1.266674e+02    125.863829
# 217272  1.266674e+02    125.863829
# 217273  1.266674e+02    125.863829
# 217274  1.266674e+02    125.863829
# 217275  1.266674e+02    125.863829
# 217276  1.266674e+02    125.863829
# 217277  1.266674e+02    125.863829
# 217278  1.266674e+02    125.863829
# 217279  1.266674e+02    125.863829
# 217280  1.266674e+02    125.863829
# 217281  1.266674e+02    125.863829
# 217282  1.266674e+02    125.863829
# 217283  1.266674e+02    125.863829
# 217284  1.266674e+02    125.863829
# 217285  1.266674e+02    125.863829
# 217286  1.266674e+02    125.863829
# 217287  1.266674e+02    125.863829
# 217288  1.266674e+02    125.863829
# 217289  1.266674e+02    125.863829
# 217290  1.266674e+02    125.863829
# 217291  1.266674e+02    125.863829
# 217292  1.266674e+02    125.863829
# 217293  1.266674e+02    125.863829
# 217294  1.266674e+02    125.863829
# 217295  1.266674e+02    125.863829
# 217296  1.266674e+02    125.863829
# 217297  1.266674e+02    125.863829
#
# [217298 rows x 8 columns]

# %%
# Requires 3 inputs to get to the base level of the arrays
# Every 7, it repeats

# THIS CELL HAS DATA FROM "1st Charge"

print(df['#subsystem#'][0][0][0][2][0][0])
print('\n')
print(df['#subsystem#'][0][0][0][2][0][5])# This is Time, or first column
print('\n')
len((df['#subsystem#'][0][0][0][2][0][0]))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-73-845918bc8912> in <module>()
#       3 # THIS CELL HAS DATA FROM "1st Charge"
#       4
# ----> 5 print(df['#subsystem#'][0][0][0][2][1][0])
#       6 print('\n')
#       7 print(df['#subsystem#'][0][0][0][2][0][5])# This is Time, or first column
#
# IndexError: index 1 is out of bounds for axis 0 with size 1

# %%
len(df['#subsystem#'][0][0][0][9][0][0]) # This is the second dataset
# Out:
# 1064

# %%
(df['#subsystem#'][0][0][0][16][0][0])
# Out:
# array([[  1.00007027e+01],
#        [  2.00170697e+01],
#        [  3.00326077e+01],
#        ...,
#        [  1.54987923e+04],
#        [  1.55088078e+04],
#        [  1.55148860e+04]])

# %%
58+7
# Out:
# 65

# %%
len((df['#subsystem#'][0][0][0][86][0][0]))
# Out:
# 7353

# %%
# Out:
# 11.75

# %%
df['#subsystem#'][0][0][0]
# Out:
# array([ array([[2],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=uint8),
#        array([], shape=(0, 0), dtype=float64),
#        array([[ array([[  1.00014863e+01],
#        [  2.00169123e+01],
#        [  3.00169928e+01],
#        ...,
#        [  1.12863495e+04],
#        [  1.12963499e+04],
#        [  1.13025215e+04]]),
#         array([[ 735817.60084491],
#        [ 735817.60096065],
#        [ 735817.60107639],
#        ...,
#        [ 735817.73136574],
#        [ 735817.73148148],
#        [ 735817.73155093]]),
#         array([[ 1.],
#        [ 1.],
#        [ 1.],
#        ...,
#        [ 5.],
#        [ 5.],
#        [ 5.]]),
#         array([[ 1.],
#        [ 1.],
#        [ 1.],
#        ...,
#        [ 1.],
#        [ 1.],
#        [ 1.]]),
#         array([[ 0.],
#        [ 0.],
#        [ 0.],
#        ...,
#        [ 0.],
#        [ 0.],
#        [ 0.]]),
#         array([[ 3.84519219],
#        [ 3.84519219],
#        [ 3.84535384],
#        ...,
#        [ 4.19239426],
#        [ 4.19239426],
#        [ 4.19239426]]),
#         array([[ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        ...,
#        [ 0.63367349],
#        [ 0.63367349],
#        [ 0.63367349]]),
#         array([[ 0.],
#        [ 0.],
#        [ 0.],
#        ...,
#        [ 0.],
#        [ 0.],
#        [ 0.]])]], dtype=object),
#        array([[ 2.]]), array([[ 1132.]]),
#        array([], shape=(0, 0), dtype=object), array([[ 8.]]),
#        array([[array([['Time_sec']],
#       dtype='<U8'),
#         array([['Date_Time']],
#       dtype='<U9'),
#         array([['Step']],
#       dtype='<U4'),
#         array([['Cycle']],
#       dtype='<U5'),
#         array([['Current_Amp']],
#       dtype='<U11'),
#         array([['Voltage_Volt']],
#       dtype='<U12'),
#         array([['Charge_Ah']],
#       dtype='<U9'),
#         array([['Discharge_Ah']],
#       dtype='<U12')]], dtype=object),
#        array([ ([], [], [], [], [[array([['Row']],
#       dtype='<U3'), array([['Variables']],
#       dtype='<U9')]], [[ 2.]])],
#       dtype=[('Description', '<U1', (0, 0)), ('UserData', '<f8', (0, 0)), ('VariableDescriptions', 'O', (0, 0)), ('VariableUnits', 'O', (0, 0)), ('DimensionNames', 'O', (1, 2)), ('VersionSavedFrom', '<f8', (1, 1))]),
#        array([[ array([[  1.00013775e+01],
#        [  2.00162612e+01],
#        [  3.00172554e+01],
#        ...,
#        [  1.06213194e+04],
#        [  1.06313195e+04],
#        [  1.06375383e+04]]),
#         array([[ 735818.40513889],
#        [ 735818.40525463],
#        [ 735818.40537037],
#        ...,
#        [ 735818.52796296],
#        [ 735818.5280787 ],
#        [ 735818.52814815]]),
#         array([[ 1.],
#        [ 1.],
#        [ 1.],
#        ...,
#        [ 4.],
#        [ 4.],
#        [ 4.]]),
#         array([[ 1.],
#        [ 1.],
#        [ 1.],
#        ...,
#        [ 1.],
#        [ 1.],
#        [ 1.]]),
#         array([[ 0.],
#        [ 0.],
#        [ 0.],
#        ...,
#        [ 0.],
#        [ 0.],
#        [ 0.]]),
#         array([[ 4.18802404],
#        [ 4.1878624 ],
#        [ 4.18802404],
#        ...,
#        [ 3.28448844],
#        [ 3.28465033],
#        [ 3.28465033]]),
#         array([[ 0.],
#        [ 0.],
#        [ 0.],
#        ...,
#        [ 0.],
#        [ 0.],
#        [ 0.]]),
#         array([[ 0.      ],
#        [ 0.      ],
#        [ 0.      ],
#        ...,
#        [ 1.454089],
#        [ 1.454089],
#        [ 1.454089]])]], dtype=object),
#        array([[ 2.]]), array([[ 1064.]]),
#        array([], shape=(0, 0), dtype=object), array([[ 8.]]),
#        array([[array([['Time_sec']],
#       dtype='<U8'),
#         array([['Date_Time']],
#       dtype='<U9'),
#         array([['Step']],
#       dtype='<U4'),
#         array([['Cycle']],
#       dtype='<U5'),
#         array([['Current_Amp']],
#       dtype='<U11'),
#         array([['Voltage_Volt']],
#       dtype='<U12'),
#         array([['Charge_Ah']],
#       dtype='<U9'),
#         array([['Discharge_Ah']],
#       dtype='<U12')]], dtype=object),
#        array([ ([], [], [], [], [[array([['Row']],
#       dtype='<U3'), array([['Variables']],
#       dtype='<U9')]], [[ 2.]])],
#       dtype=[('Description', '<U1', (0, 0)), ('UserData', '<f8', (0, 0)), ('VariableDescriptions', 'O', (0, 0)), ('VariableUnits', 'O', (0, 0)), ('DimensionNames', 'O', (1, 2)), ('VersionSavedFrom', '<f8', (1, 1))]),
#        array([[ array([[  1.00007027e+01],
#        [  2.00170697e+01],
#        [  3.00326077e+01],
#        ...,
#        [  1.54987923e+04],
#        [  1.55088078e+04],
#        [  1.55148860e+04]]),
#         array([[ 735818.55122685],
#        [ 735818.55134259],
#        [ 735818.55145833],
#        ...,
#        [ 735818.73049769],
#        [ 735818.73061343],
#        [ 735818.73068287]]),
#         array([[ 1.],
#        [ 1.],
#        [ 1.],
#        ...,
#        [ 5.],
#        [ 5.],
#        [ 5.]]),
#         array([[ 1.],
#        [ 1.],
#        [ 1.],
#        ...,
#        [ 1.],
#        [ 1.],
#        [ 1.]]),
#         array([[ 0.],
#        [ 0.],
#        [ 0.],
#        ...,
#        [ 0.],
#        [ 0.],
#        [ 0.]]),
#         array([[ 3.30180812],
#        [ 3.30197001],
#        [ 3.30213189],
#        ...,
#        [ 4.19190884],
#        [ 4.19190884],
#        [ 4.19190884]]),
#         array([[ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        ...,
#        [ 1.44535112],
#        [ 1.44535112],
#        [ 1.44535112]]),
#         array([[ 0.],
#        [ 0.],
#        [ 0.],
#        ...,
#        [ 0.],
#        [ 0.],
#        [ 0.]])]], dtype=object),
#        array([[ 2.]]), array([[ 1552.]]),
#        array([], shape=(0, 0), dtype=object), array([[ 8.]]),
#        array([[array([['Time_sec']],
#       dtype='<U8'),
#         array([['Date_Time']],
#       dtype='<U9'),
#         array([['Step']],
#       dtype='<U4'),
#         array([['Cycle']],
#       dtype='<U5'),
#         array([['Current_Amp']],
#       dtype='<U11'),
#         array([['Voltage_Volt']],
#       dtype='<U12'),
#         array([['Charge_Ah']],
#       dtype='<U9'),
#         array([['Discharge_Ah']],
#       dtype='<U12')]], dtype=object),
#        array([ ([], [], [], [], [[array([['Row']],
#       dtype='<U3'), array([['Variables']],
#       dtype='<U9')]], [[ 2.]])],
#       dtype=[('Description', '<U1', (0, 0)), ('UserData', '<f8', (0, 0)), ('VariableDescriptions', 'O', (0, 0)), ('VariableUnits', 'O', (0, 0)), ('DimensionNames', 'O', (1, 2)), ('VersionSavedFrom', '<f8', (1, 1))]),
#        array([[ array([[  1.00001910e+01],
#        [  2.00157947e+01],
#        [  3.00314000e+01],
#        ...,
#        [  2.16531563e+06],
#        [  2.16532563e+06],
#        [  2.16533361e+06]]),
#         array([[ 735819.42179398],
#        [ 735819.42190972],
#        [ 735819.42202546],
#        ...,
#        [ 735844.48420139],
#        [ 735844.48431713],
#        [ 735844.48440972]]),
#         array([[  1.],
#        [  1.],
#        [  1.],
#        ...,
#        [ 13.],
#        [ 13.],
#        [ 13.]]),
#         array([[   1.],
#        [   1.],
#        [   1.],
#        ...,
#        [ 102.],
#        [ 102.],
#        [ 102.]]),
#         array([[ 0.],
#        [ 0.],
#        [ 0.],
#        ...,
#        [ 0.],
#        [ 0.],
#        [ 0.]]),
#         array([[ 4.18745613],
#        [ 4.18761826],
#        [ 4.18745613],
#        ...,
#        [ 4.19538879],
#        [ 4.19538879],
#        [ 4.19555044]]),
#         array([[   0.        ],
#        [   0.        ],
#        [   0.        ],
#        ...,
#        [ 144.09410856],
#        [ 144.09410856],
#        [ 144.09410856]]),
#         array([[   0.        ],
#        [   0.        ],
#        [   0.        ],
#        ...,
#        [ 143.41356606],
#        [ 143.41356606],
#        [ 143.41356606]])]], dtype=object),
#        array([[ 2.]]), array([[ 216876.]]),
#        array([], shape=(0, 0), dtype=object), array([[ 8.]]),
#        array([[array([['Time_sec']],
#       dtype='<U8'),
#         array([['Date_Time']],
#       dtype='<U9'),
#         array([['Step']],
#       dtype='<U4'),
#         array([['Cycle']],
#       dtype='<U5'),
#         array([['Current_Amp']],
#       dtype='<U11'),
#         array([['Voltage_Volt']],
#       dtype='<U12'),
#         array([['Charge_Ah']],
#       dtype='<U9'),
#         array([['Discharge_Ah']],
#       dtype='<U12')]], dtype=object),
#        array([ ([], [], [], [], [[array([['Row']],
#       dtype='<U3'), array([['Variables']],
#       dtype='<U9')]], [[ 2.]])],
#       dtype=[('Description', '<U1', (0, 0)), ('UserData', '<f8', (0, 0)), ('VariableDescriptions', 'O', (0, 0)), ('VariableUnits', 'O', (0, 0)), ('DimensionNames', 'O', (1, 2)), ('VersionSavedFrom', '<f8', (1, 1))]),
#        array([[ array([[  1.00002762e+01],
#        [  2.00003431e+01],
#        [  3.00161074e+01],
#        ...,
#        [  2.09500004e+06],
#        [  2.09501005e+06],
#        [  2.09501746e+06]]),
#         array([[ 735845.3975463 ],
#        [ 735845.39766204],
#        [ 735845.39777778],
#        ...,
#        [ 735870.16829861],
#        [ 735870.16841435],
#        [ 735870.16849537]]),
#         array([[  1.],
#        [  1.],
#        [  1.],
#        ...,
#        [ 13.],
#        [ 13.],
#        [ 13.]]),
#         array([[   1.],
#        [   1.],
#        [   1.],
#        ...,
#        [ 102.],
#        [ 102.],
#        [ 102.]]),
#         array([[ 0.],
#        [ 0.],
#        [ 0.],
#        ...,
#        [ 0.],
#        [ 0.],
#        [ 0.]]),
#         array([[ 4.19053221],
#        [ 4.19037008],
#        [ 4.19053221],
#        ...,
#        [ 4.19506502],
#        [ 4.19538879],
#        [ 4.19506502]]),
#         array([[   0.        ],
#        [   0.        ],
#        [   0.        ],
#        ...,
#        [ 141.37663871],
#        [ 141.37663871],
#        [ 141.37663871]]),
#         array([[   0.        ],
#        [   0.        ],
#        [   0.        ],
#        ...,
#        [ 140.60878188],
#        [ 140.60878188],
#        [ 140.60878188]])]], dtype=object),
#        array([[ 2.]]), array([[ 209854.]]),
#        array([], shape=(0, 0), dtype=object), array([[ 8.]]),
#        array([[array([['Time_sec']],
#       dtype='<U8'),
#         array([['Date_Time']],
#       dtype='<U9'),
#         array([['Step']],
#       dtype='<U4'),
#         array([['Cycle']],
#       dtype='<U5'),
#         array([['Current_Amp']],
#       dtype='<U11'),
#         array([['Voltage_Volt']],
#       dtype='<U12'),
#         array([['Charge_Ah']],
#       dtype='<U9'),
#         array([['Discharge_Ah']],
#       dtype='<U12')]], dtype=object),
#        array([ ([], [], [], [], [[array([['Row']],
#       dtype='<U3'), array([['Variables']],
#       dtype='<U9')]], [[ 2.]])],
#       dtype=[('Description', '<U1', (0, 0)), ('UserData', '<f8', (0, 0)), ('VariableDescriptions', 'O', (0, 0)), ('VariableUnits', 'O', (0, 0)), ('DimensionNames', 'O', (1, 2)), ('VersionSavedFrom', '<f8', (1, 1))]),
#        array([[ array([[  1.00001909e+01],
#        [  2.00157068e+01],
#        [  3.00312653e+01],
#        ...,
#        [  2.07163766e+06],
#        [  2.07164767e+06],
#        [  2.07165522e+06]]),
#         array([[ 735871.3921412 ],
#        [ 735871.39225694],
#        [ 735871.39237269],
#        ...,
#        [ 735895.39078704],
#        [ 735895.39090278],
#        [ 735895.39099537]]),
#         array([[  1.],
#        [  1.],
#        [  1.],
#        ...,
#        [ 13.],
#        [ 13.],
#        [ 13.]]),
#         array([[   1.],
#        [   1.],
#        [   1.],
#        ...,
#        [ 102.],
#        [ 102.],
#        [ 102.]]),
#         array([[ 0.],
#        [ 0.],
#        [ 0.],
#        ...,
#        [ 0.],
#        [ 0.],
#        [ 0.]]),
#         array([[ 4.18988466],
#        [ 4.19020844],
#        [ 4.19004631],
#        ...,
#        [ 4.19538879],
#        [ 4.19538879],
#        [ 4.19555044]]),
#         array([[   0.        ],
#        [   0.        ],
#        [   0.        ],
#        ...,
#        [ 139.43506638],
#        [ 139.43506638],
#        [ 139.43506638]]),
#         array([[   0.        ],
#        [   0.        ],
#        [   0.        ],
#        ...,
#        [ 138.77698613],
#        [ 138.77698613],
#        [ 138.77698613]])]], dtype=object),
#        array([[ 2.]]), array([[ 207482.]]),
#        array([], shape=(0, 0), dtype=object), array([[ 8.]]),
#        array([[array([['Time_sec']],
#       dtype='<U8'),
#         array([['Date_Time']],
#       dtype='<U9'),
#         array([['Step']],
#       dtype='<U4'),
#         array([['Cycle']],
#       dtype='<U5'),
#         array([['Current_Amp']],
#       dtype='<U11'),
#         array([['Voltage_Volt']],
#       dtype='<U12'),
#         array([['Charge_Ah']],
#       dtype='<U9'),
#         array([['Discharge_Ah']],
#       dtype='<U12')]], dtype=object),
#        array([ ([], [], [], [], [[array([['Row']],
#       dtype='<U3'), array([['Variables']],
#       dtype='<U9')]], [[ 2.]])],
#       dtype=[('Description', '<U1', (0, 0)), ('UserData', '<f8', (0, 0)), ('VariableDescriptions', 'O', (0, 0)), ('VariableUnits', 'O', (0, 0)), ('DimensionNames', 'O', (1, 2)), ('VersionSavedFrom', '<f8', (1, 1))]),
#        array([[ array([[  1.00155806e+01],
#        [  2.00309850e+01],
#        [  3.00465067e+01],
#        ...,
#        [  2.03570145e+06],
#        [  2.03571145e+06],
#        [  2.03572058e+06]]),
#         array([[ 735921.53315972],
#        [ 735921.53327546],
#        [ 735921.5333912 ],
#        ...,
#        [ 735945.76474537],
#        [ 735945.76486111],
#        [ 735945.76496528]]),
#         array([[  1.],
#        [  1.],
#        [  1.],
#        ...,
#        [ 13.],
#        [ 13.],
#        [ 13.]]),
#         array([[   1.],
#        [   1.],
#        [   1.],
#        ...,
#        [ 102.],
#        [ 102.],
#        [ 102.]]),
#         array([[ 0.],
#        [ 0.],
#        [ 0.],
#        ...,
#        [ 0.],
#        [ 0.],
#        [ 0.]]),
#         array([[ 4.18033361],
#        [ 4.18017149],
#        [ 4.18017149],
#        ...,
#        [ 4.19587421],
#        [ 4.19571257],
#        [ 4.19571257]]),
#         array([[   0.        ],
#        [   0.        ],
#        [   0.        ],
#        ...,
#        [ 138.08257671],
#        [ 138.08257671],
#        [ 138.08257671]]),
#         array([[   0.        ],
#        [   0.        ],
#        [   0.        ],
#        ...,
#        [ 137.53126328],
#        [ 137.53126328],
#        [ 137.53126328]])]], dtype=object),
#        array([[ 2.]]), array([[ 203944.]]),
#        array([], shape=(0, 0), dtype=object), array([[ 8.]]),
#        array([[array([['Time_sec']],
#       dtype='<U8'),
#         array([['Date_Time']],
#       dtype='<U9'),
#         array([['Step']],
#       dtype='<U4'),
#         array([['Cycle']],
#       dtype='<U5'),
#         array([['Current_Amp']],
#       dtype='<U11'),
#         array([['Voltage_Volt']],
#       dtype='<U12'),
#         array([['Charge_Ah']],
#       dtype='<U9'),
#         array([['Discharge_Ah']],
#       dtype='<U12')]], dtype=object),
#        array([ ([], [], [], [], [[array([['Row']],
#       dtype='<U3'), array([['Variables']],
#       dtype='<U9')]], [[ 2.]])],
#       dtype=[('Description', '<U1', (0, 0)), ('UserData', '<f8', (0, 0)), ('VariableDescriptions', 'O', (0, 0)), ('VariableUnits', 'O', (0, 0)), ('DimensionNames', 'O', (1, 2)), ('VersionSavedFrom', '<f8', (1, 1))]),
#        array([[ array([[  1.00155469e+01],
#        [  2.00311243e+01],
#        [  3.00467349e+01],
#        ...,
#        [  2.04847403e+06],
#        [  2.04848403e+06],
#        [  2.04849161e+06]]),
#         array([[ 735955.50060185],
#        [ 735955.50071759],
#        [ 735955.50083333],
#        ...,
#        [ 736002.42792824],
#        [ 736002.42804398],
#        [ 736002.42813657]]),
#         array([[  1.],
#        [  1.],
#        [  1.],
#        ...,
#        [ 13.],
#        [ 13.],
#        [ 13.]]),
#         array([[   1.],
#        [   1.],
#        [   1.],
#        ...,
#        [ 102.],
#        [ 102.],
#        [ 102.]]),
#         array([[ 0.],
#        [ 0.],
#        [ 0.],
#        ...,
#        [ 0.],
#        [ 0.],
#        [ 0.]]),
#         array([[ 4.19069386],
#        [ 4.19085598],
#        [ 4.19085598],
#        ...,
#        [ 4.19506502],
#        [ 4.19506502],
#        [ 4.19506502]]),
#         array([[   0.        ],
#        [   0.        ],
#        [   0.        ],
#        ...,
#        [ 136.22192917],
#        [ 136.22192917],
#        [ 136.22192917]]),
#         array([[   0.        ],
#        [   0.        ],
#        [   0.        ],
#        ...,
#        [ 135.63800352],
#        [ 135.63800352],
#        [ 135.63800352]])]], dtype=object),
#        array([[ 2.]]), array([[ 205229.]]),
#        array([], shape=(0, 0), dtype=object), array([[ 8.]]),
#        array([[array([['Time_sec']],
#       dtype='<U8'),
#         array([['Date_Time']],
#       dtype='<U9'),
#         array([['Step']],
#       dtype='<U4'),
#         array([['Cycle']],
#       dtype='<U5'),
#         array([['Current_Amp']],
#       dtype='<U11'),
#         array([['Voltage_Volt']],
#       dtype='<U12'),
#         array([['Charge_Ah']],
#       dtype='<U9'),
#         array([['Discharge_Ah']],
#       dtype='<U12')]], dtype=object),
#        array([ ([], [], [], [], [[array([['Row']],
#       dtype='<U3'), array([['Variables']],
#       dtype='<U9')]], [[ 2.]])],
#       dtype=[('Description', '<U1', (0, 0)), ('UserData', '<f8', (0, 0)), ('VariableDescriptions', 'O', (0, 0)), ('VariableUnits', 'O', (0, 0)), ('DimensionNames', 'O', (1, 2)), ('VersionSavedFrom', '<f8', (1, 1))]),
#        array([[ array([[  1.00002328e+01],
#        [  2.00156573e+01],
#        [  3.00310688e+01],
#        ...,
#        [  2.11018830e+06],
#        [  2.11019832e+06],
#        [  2.11020582e+06]]),
#         array([[ 736035.45950231],
#        [ 736035.45961806],
#        [ 736035.4597338 ],
#        ...,
#        [ 736075.72684028],
#        [ 736075.72695602],
#        [ 736075.72703704]]),
#         array([[  1.],
#        [  1.],
#        [  1.],
#        ...,
#        [ 13.],
#        [ 13.],
#        [ 13.]]),
#         array([[   1.],
#        [   1.],
#        [   1.],
#        ...,
#        [ 102.],
#        [ 102.],
#        [ 102.]]),
#         array([[ 0.],
#        [ 0.],
#        [ 0.],
#        ...,
#        [ 0.],
#        [ 0.],
#        [ 0.]]),
#         array([[ 4.1816287 ],
#        [ 4.1816287 ],
#        [ 4.18179035],
#        ...,
#        [ 4.19263649],
#        [ 4.19263649],
#        [ 4.19263649]]),
#         array([[   0.        ],
#        [   0.        ],
#        [   0.        ],
#        ...,
#        [ 130.47565203],
#        [ 130.47565203],
#        [ 130.47565203]]),
#         array([[   0.        ],
#        [   0.        ],
#        [   0.        ],
#        ...,
#        [ 129.70237875],
#        [ 129.70237875],
#        [ 129.70237875]])]], dtype=object),
#        array([[ 2.]]), array([[ 211321.]]),
#        array([], shape=(0, 0), dtype=object), array([[ 8.]]),
#        array([[array([['Time_sec']],
#       dtype='<U8'),
#         array([['Date_Time']],
#       dtype='<U9'),
#         array([['Step']],
#       dtype='<U4'),
#         array([['Cycle']],
#       dtype='<U5'),
#         array([['Current_Amp']],
#       dtype='<U11'),
#         array([['Voltage_Volt']],
#       dtype='<U12'),
#         array([['Charge_Ah']],
#       dtype='<U9'),
#         array([['Discharge_Ah']],
#       dtype='<U12')]], dtype=object),
#        array([ ([], [], [], [], [[array([['Row']],
#       dtype='<U3'), array([['Variables']],
#       dtype='<U9')]], [[ 2.]])],
#       dtype=[('Description', '<U1', (0, 0)), ('UserData', '<f8', (0, 0)), ('VariableDescriptions', 'O', (0, 0)), ('VariableUnits', 'O', (0, 0)), ('DimensionNames', 'O', (1, 2)), ('VersionSavedFrom', '<f8', (1, 1))]),
#        array([[ array([[  1.00154040e+01],
#        [  2.00309105e+01],
#        [  3.00465791e+01],
#        ...,
#        [  2.17003949e+06],
#        [  2.17004951e+06],
#        [  2.17005674e+06]]),
#         array([[ 736077.44351852],
#        [ 736077.44363426],
#        [ 736077.44375   ],
#        ...,
#        [ 736102.56079861],
#        [ 736102.56091435],
#        [ 736102.56100694]]),
#         array([[  1.],
#        [  1.],
#        [  1.],
#        ...,
#        [ 13.],
#        [ 13.],
#        [ 13.]]),
#         array([[   1.],
#        [   1.],
#        [   1.],
#        ...,
#        [ 102.],
#        [ 102.],
#        [ 102.]]),
#         array([[ 0.],
#        [ 0.],
#        [ 0.],
#        ...,
#        [ 0.],
#        [ 0.],
#        [ 0.]]),
#         array([[ 4.1699729 ],
#        [ 4.17013454],
#        [ 4.1699729 ],
#        ...,
#        [ 4.19166517],
#        [ 4.19166517],
#        [ 4.19150352]]),
#         array([[   0.        ],
#        [   0.        ],
#        [   0.        ],
#        ...,
#        [ 126.66738273],
#        [ 126.66738273],
#        [ 126.66738273]]),
#         array([[   0.        ],
#        [   0.        ],
#        [   0.        ],
#        ...,
#        [ 125.86382907],
#        [ 125.86382907],
#        [ 125.86382907]])]], dtype=object),
#        array([[ 2.]]), array([[ 217298.]]),
#        array([], shape=(0, 0), dtype=object), array([[ 8.]]),
#        array([[array([['Time_sec']],
#       dtype='<U8'),
#         array([['Date_Time']],
#       dtype='<U9'),
#         array([['Step']],
#       dtype='<U4'),
#         array([['Cycle']],
#       dtype='<U5'),
#         array([['Current_Amp']],
#       dtype='<U11'),
#         array([['Voltage_Volt']],
#       dtype='<U12'),
#         array([['Charge_Ah']],
#       dtype='<U9'),
#         array([['Discharge_Ah']],
#       dtype='<U12')]], dtype=object),
#        array([ ([], [], [], [], [[array([['Row']],
#       dtype='<U3'), array([['Variables']],
#       dtype='<U9')]], [[ 2.]])],
#       dtype=[('Description', '<U1', (0, 0)), ('UserData', '<f8', (0, 0)), ('VariableDescriptions', 'O', (0, 0)), ('VariableUnits', 'O', (0, 0)), ('DimensionNames', 'O', (1, 2)), ('VersionSavedFrom', '<f8', (1, 1))]),
#        array([[ array([[  1.00153151e+01],
#        [  2.00307793e+01],
#        [  3.00462923e+01],
#        ...,
#        [  2.23512218e+06],
#        [  2.23513220e+06],
#        [  2.23514220e+06]]),
#         array([[ 736112.50135417],
#        [ 736112.50146991],
#        [ 736112.50158565],
#        ...,
#        [ 736139.29184028],
#        [ 736139.29195602],
#        [ 736139.29207176]]),
#         array([[  1.],
#        [  1.],
#        [  1.],
#        ...,
#        [ 13.],
#        [ 13.],
#        [ 13.]]),
#         array([[   1.],
#        [   1.],
#        [   1.],
#        ...,
#        [ 102.],
#        [ 102.],
#        [ 102.]]),
#         array([[ 0.],
#        [ 0.],
#        [ 0.],
#        ...,
#        [ 0.],
#        [ 0.],
#        [ 0.]]),
#         array([[ 4.15734577],
#        [ 4.15734577],
#        [ 4.15734577],
#        ...,
#        [ 4.19733143],
#        [ 4.19700766],
#        [ 4.19700766]]),
#         array([[   0.        ],
#        [   0.        ],
#        [   0.        ],
#        ...,
#        [ 121.14341017],
#        [ 121.14341017],
#        [ 121.14341017]]),
#         array([[   0.        ],
#        [   0.        ],
#        [   0.        ],
#        ...,
#        [ 120.31136251],
#        [ 120.31136251],
#        [ 120.31136251]])]], dtype=object),
#        array([[ 2.]]), array([[ 223802.]]),
#        array([], shape=(0, 0), dtype=object), array([[ 8.]]),
#        array([[array([['Time_sec']],
#       dtype='<U8'),
#         array([['Date_Time']],
#       dtype='<U9'),
#         array([['Step']],
#       dtype='<U4'),
#         array([['Cycle']],
#       dtype='<U5'),
#         array([['Current_Amp']],
#       dtype='<U11'),
#         array([['Voltage_Volt']],
#       dtype='<U12'),
#         array([['Charge_Ah']],
#       dtype='<U9'),
#         array([['Discharge_Ah']],
#       dtype='<U12')]], dtype=object),
#        array([ ([], [], [], [], [[array([['Row']],
#       dtype='<U3'), array([['Variables']],
#       dtype='<U9')]], [[ 2.]])],
#       dtype=[('Description', '<U1', (0, 0)), ('UserData', '<f8', (0, 0)), ('VariableDescriptions', 'O', (0, 0)), ('VariableUnits', 'O', (0, 0)), ('DimensionNames', 'O', (1, 2)), ('VersionSavedFrom', '<f8', (1, 1))]),
#        array([[ array([[  1.00154245e+01],
#        [  2.00311270e+01],
#        [  3.00466076e+01],
#        ...,
#        [  1.41665970e+06],
#        [  1.41666972e+06],
#        [  1.41667725e+06]]),
#         array([[ 736146.75287037],
#        [ 736146.75298611],
#        [ 736146.75310185],
#        ...,
#        [ 736176.43885417],
#        [ 736176.43896991],
#        [ 736176.43905093]]),
#         array([[  1.],
#        [  1.],
#        [  1.],
#        ...,
#        [ 13.],
#        [ 13.],
#        [ 13.]]),
#         array([[  1.],
#        [  1.],
#        [  1.],
#        ...,
#        [ 99.],
#        [ 99.],
#        [ 99.]]),
#         array([[ 0.],
#        [ 0.],
#        [ 0.],
#        ...,
#        [ 0.],
#        [ 0.],
#        [ 0.]]),
#         array([[ 4.1476326 ],
#        [ 4.14747047],
#        [ 4.14730883],
#        ...,
#        [ 4.19004631],
#        [ 4.18988466],
#        [ 4.19004631]]),
#         array([[   0.        ],
#        [   0.        ],
#        [   0.        ],
#        ...,
#        [ 113.74829197],
#        [ 113.74829197],
#        [ 113.74829197]]),
#         array([[   0.        ],
#        [   0.        ],
#        [   0.        ],
#        ...,
#        [ 114.03775299],
#        [ 114.03775299],
#        [ 114.03775299]])]], dtype=object),
#        array([[ 2.]]), array([[ 219943.]]),
#        array([], shape=(0, 0), dtype=object), array([[ 8.]]),
#        array([[array([['Time_sec']],
#       dtype='<U8'),
#         array([['Date_Time']],
#       dtype='<U9'),
#         array([['Step']],
#       dtype='<U4'),
#         array([['Cycle']],
#       dtype='<U5'),
#         array([['Current_Amp']],
#       dtype='<U11'),
#         array([['Voltage_Volt']],
#       dtype='<U12'),
#         array([['Charge_Ah']],
#       dtype='<U9'),
#         array([['Discharge_Ah']],
#       dtype='<U12')]], dtype=object),
#        array([ ([], [], [], [], [[array([['Row']],
#       dtype='<U3'), array([['Variables']],
#       dtype='<U9')]], [[ 2.]])],
#       dtype=[('Description', '<U1', (0, 0)), ('UserData', '<f8', (0, 0)), ('VariableDescriptions', 'O', (0, 0)), ('VariableUnits', 'O', (0, 0)), ('DimensionNames', 'O', (1, 2)), ('VersionSavedFrom', '<f8', (1, 1))]),
#        array([[ array([[  1.00001791e+01],
#        [  2.00154778e+01],
#        [  3.00155876e+01],
#        ...,
#        [  7.34311009e+04],
#        [  7.34411165e+04],
#        [  7.34486789e+04]]),
#         array([[ 736176.6221412 ],
#        [ 736176.62225694],
#        [ 736176.62237269],
#        ...,
#        [ 736177.47195602],
#        [ 736177.47207176],
#        [ 736177.47216435]]),
#         array([[  1.],
#        [  1.],
#        [  1.],
#        ...,
#        [ 13.],
#        [ 13.],
#        [ 13.]]),
#         array([[ 1.],
#        [ 1.],
#        [ 1.],
#        ...,
#        [ 4.],
#        [ 4.],
#        [ 4.]]),
#         array([[ 0.],
#        [ 0.],
#        [ 0.],
#        ...,
#        [ 0.],
#        [ 0.],
#        [ 0.]]),
#         array([[ 4.1664114 ],
#        [ 4.16624928],
#        [ 4.16624928],
#        ...,
#        [ 4.19020844],
#        [ 4.19004631],
#        [ 4.19004631]]),
#         array([[ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        ...,
#        [ 3.42396838],
#        [ 3.42396838],
#        [ 3.42396838]]),
#         array([[ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        ...,
#        [ 3.39408868],
#        [ 3.39408868],
#        [ 3.39408868]])]], dtype=object),
#        array([[ 2.]]), array([[ 7353.]]),
#        array([], shape=(0, 0), dtype=object), array([[ 8.]]),
#        array([[array([['Time_sec']],
#       dtype='<U8'),
#         array([['Date_Time']],
#       dtype='<U9'),
#         array([['Step']],
#       dtype='<U4'),
#         array([['Cycle']],
#       dtype='<U5'),
#         array([['Current_Amp']],
#       dtype='<U11'),
#         array([['Voltage_Volt']],
#       dtype='<U12'),
#         array([['Charge_Ah']],
#       dtype='<U9'),
#         array([['Discharge_Ah']],
#       dtype='<U12')]], dtype=object),
#        array([ ([], [], [], [], [[array([['Row']],
#       dtype='<U3'), array([['Variables']],
#       dtype='<U9')]], [[ 2.]])],
#       dtype=[('Description', '<U1', (0, 0)), ('UserData', '<f8', (0, 0)), ('VariableDescriptions', 'O', (0, 0)), ('VariableUnits', 'O', (0, 0)), ('DimensionNames', 'O', (1, 2)), ('VersionSavedFrom', '<f8', (1, 1))]),
#        array([[array([], shape=(0, 1), dtype=object)],
#        [ array([([],)],
#       dtype={'names':['data'], 'formats':[('O', (0, 1))], 'offsets':[0], 'itemsize':1})]], dtype=object)], dtype=object)

# %% [markdown]
# # Partial Charge Cycles

# %% [markdown]
# So this dataset has some missing data. So what that I made sure that the shape of where the data file is supposed to be isn't (0,0) (or no data). If it is, then that index just passes and moves on to the next one.

# %%
len(df2['#subsystem#'][0][0][0])
# Out:
# 157

# %%
count = 2+(7*21)
df2['#subsystem#'][0][0][0][count][0][5]
#df2['#subsystem#'][0][0][0][count][0][1].flatten().shape
# Out:
# array([[ 4.18917894],
#        [ 4.1890173 ],
#        [ 4.18934107],
#        ...,
#        [ 4.1975975 ],
#        [ 4.1975975 ],
#        [ 4.19743538]])

# %%
7*17
# Out:
# 119

# %%
len(df2['#subsystem#'][0][0][0])
# Out:
# 157

# %%
df2['converted_PL03'][15][2].shape == (0,0)
# Out:
# True

# %%
count = 9
host_df = pd.DataFrame()

host_df['time'] = df2['#subsystem#'][0][0][0][count][0][0].flatten()
host_df['datetime'] = df2['#subsystem#'][0][0][0][count][0][1].flatten()
host_df['step'] = df2['#subsystem#'][0][0][0][count][0][2].flatten()
host_df['cycle'] = df2['#subsystem#'][0][0][0][count][0][3].flatten()
host_df['current_amp'] = df2['#subsystem#'][0][0][0][count][0][4].flatten()
host_df['voltage'] = df2['#subsystem#'][0][0][0][count][0][5].flatten()
host_df['charge_ah'] = df2['#subsystem#'][0][0][0][count][0][6].flatten()
host_df['discharge_ah'] = df2['#subsystem#'][0][0][0][count][0][7].flatten()

# %%
data_dict_partial_cycle = {}
count = int(2)

for idx in range(1, len(df2['converted_PL03'])):
    operation = str(df2['converted_PL03'][idx][0][0][0])
    start_date = str(df2['converted_PL03'][idx][1][0][0])
    
    if df2['converted_PL03'][idx][2].shape == (0,0):
        pass
    
    else:
    
        host_df = pd.DataFrame()

        host_df['time'] = df2['#subsystem#'][0][0][0][count][0][0].flatten()
        host_df['datetime'] = df2['#subsystem#'][0][0][0][count][0][1].flatten
        host_df['step'] = df2['#subsystem#'][0][0][0][count][0][2].flatten()
        host_df['cycle'] = df2['#subsystem#'][0][0][0][count][0][3].flatten()
        host_df['current_amp'] = df2['#subsystem#'][0][0][0][count][0][4].flatten()
        host_df['voltage'] = df2['#subsystem#'][0][0][0][count][0][5].flatten()
        host_df['charge_ah'] = df2['#subsystem#'][0][0][0][count][0][6].flatten()
        host_df['discharge_ah'] = df2['#subsystem#'][0][0][0][count][0][7].flatten()

        data_dict_partial_cycle[operation + ' ' + start_date] = host_df

        count = count + 7

        if count > len(df2['#subsystem#'][0][0][0]):
            break
    
    #op.append(operation)
    #start_d.append(start_date)

# %%
data_dict_partial_cycle['50 Partial Cycles April 14, 2015'].tail()
# Out:
#                  time                                           datetime  \
# 121747  609591.644376  <built-in method flatten of numpy.ndarray obje...
# 121748  609596.659949  <built-in method flatten of numpy.ndarray obje...
# 121749  609601.675419  <built-in method flatten of numpy.ndarray obje...
# 121750  609606.691073  <built-in method flatten of numpy.ndarray obje...
# 121751  609610.972283  <built-in method flatten of numpy.ndarray obje...
#
#         step  cycle  current_amp   voltage  charge_ah  discharge_ah
# 121747  18.0   51.0          0.0  4.197065  43.796318     43.849901
# 121748  18.0   51.0          0.0  4.196903  43.796318     43.849901
# 121749  18.0   51.0          0.0  4.196741  43.796318     43.849901
# 121750  18.0   51.0          0.0  4.196903  43.796318     43.849901
# 121751  18.0   51.0          0.0  4.196903  43.796318     43.849901
