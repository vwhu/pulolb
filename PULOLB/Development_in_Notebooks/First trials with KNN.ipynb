# %% [markdown]
# First trials to code a machine learning algorithm

# %%
import pandas as pd
import numpy as np
import import_data
import sort_data
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
# %matplotlib inline
# Out:
# /Users/rossana13/miniconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
#Load the data. We need full curves and one partial curve (that represents the user's curve)

Full_Curves = sort_data.by_cycle('converted_PL11.mat')
PL03c,PL03d = sort_data.charge_discharge('converted_PL03.mat')
full_curvesc,full_curved = sort_data.charge_discharge('converted_PL11.mat')

# %%
len(PL03c.keys())
# Out:
# 1063

# %%
full_curved[102]
# Out:
#                 time       datetime  step  cycle  current_amp   voltage  \
# 216695  2.163534e+06  735844.463576  12.0  102.0    -0.000174  4.198788
#
#          charge_ah  discharge_ah
# 216695  144.094109    143.413566

# %%
full_curvesc[102]
# Out:
#                 time       datetime  step  cycle  current_amp   voltage  \
# 215663  2.153217e+06  735844.344167  10.0  102.0     0.750502  3.311980
# 215664  2.153227e+06  735844.344282  10.0  102.0     0.750320  3.349538
# 215665  2.153237e+06  735844.344398  10.0  102.0     0.750320  3.380296
# 215666  2.153247e+06  735844.344514  10.0  102.0     0.750502  3.407169
# 215667  2.153257e+06  735844.344630  10.0  102.0     0.750502  3.430804
# 215668  2.153267e+06  735844.344745  10.0  102.0     0.750502  3.452335
# 215669  2.153277e+06  735844.344861  10.0  102.0     0.750320  3.471761
# 215670  2.153287e+06  735844.344977  10.0  102.0     0.750139  3.489731
# 215671  2.153297e+06  735844.345093  10.0  102.0     0.750320  3.506567
# 215672  2.153307e+06  735844.345208  10.0  102.0     0.750320  3.521946
# 215673  2.153317e+06  735844.345324  10.0  102.0     0.750502  3.536515
# 215674  2.153327e+06  735844.345440  10.0  102.0     0.750320  3.549790
# 215675  2.153337e+06  735844.345556  10.0  102.0     0.750320  3.562741
# 215676  2.153347e+06  735844.345671  10.0  102.0     0.750502  3.574882
# 215677  2.153357e+06  735844.345787  10.0  102.0     0.750502  3.586214
# 215678  2.153367e+06  735844.345903  10.0  102.0     0.750320  3.597060
# 215679  2.153377e+06  735844.346019  10.0  102.0     0.750320  3.607421
# 215680  2.153387e+06  735844.346134  10.0  102.0     0.750139  3.617296
# 215681  2.153397e+06  735844.346250  10.0  102.0     0.750320  3.626686
# 215682  2.153407e+06  735844.346366  10.0  102.0     0.750502  3.635751
# 215683  2.153417e+06  735844.346481  10.0  102.0     0.750502  3.644493
# 215684  2.153427e+06  735844.346597  10.0  102.0     0.750502  3.652749
# 215685  2.153437e+06  735844.346713  10.0  102.0     0.750502  3.660843
# 215686  2.153447e+06  735844.346829  10.0  102.0     0.750865  3.668290
# 215687  2.153457e+06  735844.346956  10.0  102.0     0.750502  3.676060
# 215688  2.153467e+06  735844.347072  10.0  102.0     0.750865  3.683022
# 215689  2.153477e+06  735844.347187  10.0  102.0     0.750139  3.689983
# 215690  2.153487e+06  735844.347303  10.0  102.0     0.750502  3.696782
# 215691  2.153497e+06  735844.347419  10.0  102.0     0.750320  3.703095
# 215692  2.153507e+06  735844.347535  10.0  102.0     0.750502  3.709085
# 215685  142.730299    143.413566
# 215686  142.732386    143.413566
# 215687  142.734474    143.413566
# 215688  142.736559    143.413566
# 215689  142.738649    143.413566
# 215690  142.740737    143.413566
# 215691  142.742825    143.413566
# 215692  142.744909    143.413566
# ...            ...           ...
# 216665  144.092581    143.413566
# 216666  144.092639    143.413566
# 216667  144.092696    143.413566
# 216668  144.092754    143.413566
# 216669  144.092811    143.413566
# 216670  144.092868    143.413566
# 216671  144.092922    143.413566
# 216672  144.092977    143.413566
# 216673  144.093031    143.413566
# 216674  144.093086    143.413566
# 216675  144.093140    143.413566
# 216676  144.093194    143.413566
# 216677  144.093247    143.413566
# 216678  144.093301    143.413566
# 216679  144.093354    143.413566
# 216680  144.093407    143.413566
# 216681  144.093459    143.413566
# 216682  144.093511    143.413566
# 216683  144.093563    143.413566
# 216684  144.093615    143.413566
# 216685  144.093666    143.413566
# 216686  144.093717    143.413566
# 216687  144.093768    143.413566
# 216688  144.093818    143.413566
# 216689  144.093868    143.413566
# 216690  144.093918    143.413566
# 216691  144.093967    143.413566
# 216692  144.094016    143.413566
# 216693  144.094065    143.413566
# 216694  144.094109    143.413566
#
# [1032 rows x 8 columns]

# %% [markdown]
# #plt.figure(figsize = (6, 6))
# for i in range(1, len(discharge.keys()), 41):
#     if i in discharge.keys():
#         plt.plot((discharge[i]['time']-discharge[i]['time'].iloc[0]), discharge[i]['voltage'])
#     else:
#         pass
# plt.title('Discharge Curves')
# plt.show()

# %%
Cu = PL03c[10]['voltage']
x1 = np.linspace(1, len(Cu), num=len(Cu))

# %%
plt.plot(x1,Cu)

# %%
Cu = PL03d[10]['voltage']
x1 = np.linspace(1, len(Cu), num=len(Cu))

# %%
plt.plot(x1,Cu)

# %%
Fu = full_curved[10][['voltage']]
x2 = np.linspace(1, len(Fu), num=len(Fu))

# %%
plt.plot(x2,Fu)

# %%
Fu = full_curvesc[10][['voltage']]
x2 = np.linspace(1, len(Fu), num=len(Fu))

# %%
plt.plot(x2,Fu)

# %%
a = PL03c[444]['voltage'].values.flatten()

b = Full_Curves[1][['voltage']].values.flatten()

# %%
len(a)
# Out:
# 802

# %%
len(b)
# Out:
# 1175

# %%
from scipy.spatial.distance import euclidean
from fastdtw import fastdtw

a = PL03d[100]['voltage'].values.flatten()
b = full_curved[1][['voltage']].values.flatten()
distance,path = fastdtw(a, b, dist=euclidean)
print(distance)
# Out:
# 21.55074954032898

# %%
from scipy.spatial.distance import euclidean
from fastdtw import fastdtw

def curve_distance(a,b):
#Inputs are two nparray    
    distance,path = fastdtw(a, b, dist=euclidean)
    return distance

# %%
curve_distance(PL03d[100]['voltage'].values.flatten(),full_curved[1][['voltage']].values.flatten())
# Out:
# 21.55074954032898

# %%
def distance_to_full(curve,dic):
#Inputs are one partial curve and a dictionary with full curves
    a = curve.values.flatten()
    Y = []
    
    for i in range(1,4): #Trial with random range
        if i in dic.keys():
            b = dic[i][['voltage']].values.flatten() 
            d = curve_distance(a,b)
            
            A = [i,d]
            Y.append(A)
        else:
            pass
    df = pd.DataFrame(Y, columns = ['Cycle','Distance'])
    df = df.sort_values(by = ['Distance'])
    return df

# %%
distance_to_full(PL03d[100]['voltage'],full_curved)
# Out:
#    Cycle   Distance
# 0      1  21.550750
# 1      2  21.803970
# 2      3  21.879198

# %%
def distance_to_full(curve,dic):
#Inputs are one partial curve and a dictionary with full curves
    a = curve.values.flatten()
    Y = []
    
    for i in range(1,len(dic.keys()) + 1):
        if i in dic.keys():
            b = dic[i][['voltage']].values.flatten()
            if len(b) > 100: #This is to mae sure the full curve has values (check curve 102, it has only 1 value) 
                d = curve_distance(a,b)
            
                A = [i,d]
                Y.append(A)
            else:
                pass
        else:
            pass
    df = pd.DataFrame(Y, columns = ['Cycle','Distance'])
    df = df.sort_values(by = ['Distance'])
    return df

# %%
distance_to_full(PL03d[1]['voltage'],full_curved)
# Out:
#      Cycle  Distance
# 395    400  0.579620
# 240    244  0.596118
# 375    380  0.609299
# 402    475  0.614392
# 254    258  0.617350
# 250    254  0.622014
# 433    506  0.622286
# 259    263  0.622513
# 252    256  0.623136
# 166    169  0.623744
# 156    159  0.627170
# 374    379  0.629946
# 325    330  0.630450
# 44      45  0.630461
# 399    404  0.631921
# 419    492  0.632455
# 246    250  0.632618
# 193    196  0.633030
# 362    367  0.633045
# 430    503  0.634005
# 195    198  0.634305
# 213    217  0.635022
# 46      47  0.636147
# 58      59  0.636430
# 175    178  0.636947
# 191    194  0.637156
# 232    236  0.637683
# 248    252  0.639793
# 47      48  0.639820
# 349    354  0.641848
# ..     ...       ...
# 739    816  1.573270
# 741    818  1.601465
# 750    827  1.607270
# 752    829  1.615714
# 749    826  1.623869
# 751    828  1.631415
# 754    831  1.637468
# 714    790  1.797316
# 742    819  1.831539
# 715    791  1.861165
# 712    788  1.861410
# 713    789  1.905105
# 721    797  1.923064
# 717    793  1.929627
# 726    802  1.965035
# 722    798  1.967557
# 716    792  1.979501
# 730    806  1.999733
# 720    796  2.013448
# 727    803  2.027044
# 718    794  2.034216
# 724    800  2.037201
# 728    804  2.045661
# 725    801  2.049448
# 719    795  2.053334
# 723    799  2.056907
# 729    805  2.098824
# 732    808  2.139302
# 731    807  2.143991
# 733    809  2.175455
#
# [757 rows x 2 columns]

# %%
Cu = PL03d[1]['voltage']
x1 = np.linspace(1, len(Cu), num=len(Cu))

# %%
plt.plot(x1,Cu)

# %%
Fu = full_curved[400][['voltage']]
x2 = np.linspace(1, len(Fu), num=len(Fu))

# %%
plt.plot(x2,Fu)

# %%
def Predict_Cycle(df):
    Cycle = df['Cycle'][df.index[0]]
    return Cycle

# %%
def KNN(curve,dic,t):
    df = distance_to_full(curve,dic)
    Cycle = Predict_Cycle(df)
    full_curve = dic[Cycle]
    
    corr_factor = t/10 #10 seconds is the measurements time in the full cycle data
    Cycle = Cycle*corr_factor
    return Cycle , full_curve

# %%
KNN(PL03d[444]['voltage'],full_curved,5)

# %%
KNN(PL03d[100]['voltage'],full_curved,5)
